# %%
import pathlib 
import numpy as np
from random import shuffle
import ipywidgets as widgets
import pandas as pd
import re
import altair as alt


from whatlies.language import CountVectorLanguage, BytePairLanguage, SentenceTFMLanguage, LaBSELanguage
from whatlies.transformers import Pca, Umap
from whatlies import EmbeddingSet

from hulearn.preprocessing import InteractivePreprocessor
from hulearn.experimental.interactive import InteractiveCharts

# %%
# lang_cv  = CountVectorLanguage(10)
# lang_bp  = BytePairLanguage("he", dim=300, vs=200_000)
# lang_LaBSEL = LaBSELanguage()

# %%
def description_preprocessing(description):
    description = description.lower()
    description = re.sub(r"[״׳`!*~.()/,?+-]", " ", description)
    description = description.replace('  ', ' ')
    description = re.sub(r"\"", "", description)
    description = re.sub(r"\'", "", description)
    description = ''.join([i for i in description if not i.isdigit()])
    description = description.replace('   ', ' ')
    description = description.replace('  ', ' ')    
    description = description.strip()

    return description

# %%
txt = pathlib.Path("nlu-multi.md").read_text()
texts = list(set([t.replace("- ", "") for t in txt.split("\n") if len(t) > 0 and t[0] != "#"]))
print(f"We're going to plot {len(texts)} texts.")

shuffle(texts)
# Out:
# We're going to plot 648 texts.

# %%
texts
# Out:
# ['את חמודה חחחח',
#  'you are so handsome',
#  'לא מעוניין בשיחה הזאת',
#  'а oткуда вы',
#  'בבקשה תהיה חבר שלי',
#  "you're looking good today",
#  'שלום לך עוזר',
#  'מה תאריך הלידה שלך',
#  'your town',
#  'Ну и спасибо тебе',
#  'בוקר מקסים',
#  'אני רוצה שאני ואתה נהיה חברים',
#  'Привет',
#  'thank you my friend',
#  'you look great today',
#  'אני לא מעוניין לדבר איתך',
#  'Сколько тебе лет',
#  'רק בדיקה',
#  'מה שם משפחה שלך',
#  'תספרי לי מה השם שלך',
#  'שלום שלום',
#  'ניסיון',
#  "You know today it's my bday ",
#  'אני מדוכאת',
#  'לא מעוניין לדבר',
#  'המון המון תודה',
#  "let's not talk",
#  'את נראית מעולה',
#  'hey',
#  'you are looking so beautiful',
#  'אני חברה שלך',
#  'שכחתי את השם שלך',
#  'hey buddy',
#  'באיזה רחוב אתה גר',
#  'את ממש מקסימה',
#  'your age',
#  'אני מתעייף',
#  'שלום וברכה',
#  'I am really tired',
#  'oka',
#  'מאיזה מקופ אתה בארץ',
#  "I'm not in a mood to talk",
#  'אני מעוניין לסיים את השיחה',
#  'מאיזה מקום אתה',
#  'you are my best friend',
#  'בסדר תודה',
#  'You look aged',
#  'hey there',
#  'are we best friends',
#  'you are looking beautiful today',
#  'thanks buddy',
#  'אני עייפה',
#  'לכי תחפשי',
#  'hey man',
#  'я праздную день рождения',
#  'דיברנו מספיק',
#  'אנחנו חברים טובים',
#  'יש לך יום הולדת היום',
#  'אתה חבר טוב שלי',
#  'תודה אלוף',
#  'אני לא רוצה לדבר איתך יותר',
#  "I'm so tired",
#  'שלום',
#  'מגורים',
#  'אתה מאוד נאה',
#  'אני אוהב את איך שאתה נראה',
#  'תגיד לי תכתובת שלך',
#  'I grow weary',
#  'what is your name',
#  "no thank you that's all",
#  'את גרה קרוב',
#  'מה שמל',
#  'תומר לי את שמך',
#  'thank you that will be all',
#  'בואי נהיה חברים',
#  'הי בוט',
#  'I am tired',
#  'אהלן אחי',
#  'בואי נסיים',
#  'you are my bestie',
#  'will you be my friend',
#  'your hometown?',
#  'you are really cute',
#  'you are very beautiful',
#  'you are looking great',
#  'אני רוצה שאנחנו נהיה חברים',
#  'אפשר לבחון אותך',
#  'you are cute',
#  'מתי יום ההולדת שלך',
#  '😕',
#  'זה מבחן',
#  'מקום המגורים שלך',
#  'אתה נראה מדהים',
#  'איזה עייפות',
#  "you're so gorgeous",
#  'תודה זה רק ניסיון',
#  'כמה זמן אתה קיים',
#  'where do you live',
#  'do you want to be my friend',
#  'תודה השאלה לא בתחום',
#  'בוקר מקסים ידידי',
#  'where is your home',
#  'you are looking so good',
#  'בוקר סבבה',
#  "what's your age?",
#  'תגיד לי מה הגיל שלך',
#  'проверка',
#  'здрасте',
#  'большое спасибо',
#  'את רוצה להיות חברה שלי',
#  'how old are you?',
#  "lovely day isn't it",
#  'you are looking awesome',
#  'מתי יש לך יום הולדת',
#  'אתה כלכך יפה',
#  'איפה אתה מתגורר',
#  'доброе утречко',
#  'איפה הבית שלך',
#  'А как вас зовут',
#  'בוקר',
#  'תודה מלך',
#  'terrific thank you',
#  'איפה אתה גר',
#  'I am your friend',
#  'איך קוראים לך',
#  'שלום לכם',
#  'thanks',
#  'מה הגיל שלך',
#  'How old did you turn?',
#  'תודה על הרעיון הנהדר',
#  'אתה גר רחוק',
#  'בוקר טוב עוזר שלי',
#  'I am little tired',
#  'תאריך לידה',
#  'המון תודות',
#  "I'm getting tired",
#  'מליוני תודות',
#  'thanks again',
#  'היי עוזרת האישית',
#  'תגיד לי את הגיל שלך',
#  'אניר רוצה לדעת את השם',
#  'приветик',
#  'אני לא רוצה שנדבר יותר',
#  'in which city do you live',
#  'את נראית נפלא',
#  'long time no see',
#  'test',
#  'שם שלך',
#  'I need to know your name',
#  'תן לי את הכתובת שלך',
#  'אני לא מעוניין לשמוע אותך',
#  'איך קוראים לו',
#  'איך אתה נקרא',
#  'בוקר טוב גם לך',
#  "you're tested",
#  'how long have you been live?',
#  'אין לי אנרגיה',
#  "you're looking good",
#  'GM',
#  'У меня нет сил',
#  'אני רוצה להודות לך',
#  'чудесное утро',
#  'אתה בן 21',
#  'תודה רבה ויום טוב',
#  'את נראית פשוט נהדר',
#  'בוקר נהדר',
#  'בדיקה בדיקה 123',
#  'לא רוצה את השיחה הזאת',
#  'thank you again',
#  'מה גילך',
#  'greetings',
#  'תגיד לי את השם שלך',
#  'your home',
#  'אתה רוצה להיות חבר שלי',
#  'тест',
#  'אני במצב על פנים',
#  'תודה לך עזרת לי',
#  'tell me your age',
#  'נגמרו לי הכוחות',
#  'השמש זורחת הבוקר',
#  'you helped a lot thank you',
#  'אתה נראה פשוט נהדר',
#  'a good day',
#  'are you my friend',
#  'איפה אתה שוכן',
#  'מוודא תקינות',
#  'תאריך יום הולדתך',
#  'התעייפתי',
#  'у меня нет сил больше',
#  'שוב תודה',
#  'את חברה טובה',
#  'want to be my friend',
#  'הי',
#  'I am done talking to u',
#  'מה השם שלך',
#  'you are very attractive',
#  'בוקר מושלם',
#  'thanks love',
#  'אני בודק אותך',
#  'just testing you',
#  'How old will you be turning?',
#  'אני חבר שלך',
#  'תודה על השיחה',
#  "where's your home",
#  'where you live',
#  'אתה חבר אמת',
#  'בוקר טוב',
#  'will you be my best friend',
#  'את ממש חמודה',
#  'הי בוטית',
#  'благодарность',
#  'בוקר טוב עוזרת האישית שלי',
#  'זהו אני איבדתי את השפיות שלי',
#  'אני רוצה לסיים את השיחה',
#  'את נראית נהדר',
#  'איפה הבית שלך נמצא',
#  'you are my only friend',
#  'אני מדוכדך',
#  'אתה מכאן',
#  'אני לא רוצה לשמוע אותך יותר',
#  "I want you to know that it's my birthday today",
#  'yo man',
#  'אתה מאוד מרשים',
#  'bad time for talking',
#  'great thank you',
#  'you are my friend',
#  'היי בוקר טוב',
#  "I'm completely drained out",
#  'תודה אתקשר אתכם בפעם אחרת רעיון נהדר של מכבי',
#  'תודה אחי',
#  'איך היוצרים שלך קראו לך',
#  'I thank you',
#  'תודות',
#  'אין לי כוח אני עייף',
#  'אהלן אהלן',
#  'I want you to be my friend',
#  'you look pretty good',
#  'שלום ידידי',
#  'יש לך היום יומולדת',
#  'your house',
#  "it's my b-day",
#  'היי',
#  'אני רוצה שנהיה חברים',
#  'רע לי',
#  'салют',
#  'אתה מאוד מושך',
#  'אתה נראה טוב היום',
#  'What is your hometown?',
#  'אני בדיכאון',
#  'אני לא מדבר איתך יותר',
#  'בודק את הצאט',
#  'אתה נראה פצצה',
#  'מה עיר המגורים שלך',
#  'גיל שלך',
#  'hello',
#  'how old r u?',
#  "I think you're beautiful",
#  'את נראית מגניבה',
#  'את מהממת',
#  'תודה לכם',
#  'אפשר לקבל את הכתובת שלך',
#  'הייי',
#  'where do you live?',
#  "it's my birthday today",
#  'в каком городе вы находитесь',
#  'do you want to be my best friend',
#  'I was very tired',
#  "what's your home",
#  'we are best friends',
#  'thanks a lot',
#  'תהיי חברה שלי בבקשה',
#  'спасибочки',
#  "I'm not in the mood for chatting",
#  "where's your house",
#  'ברוך הבא',
#  'מספיק דברנו',
#  'אתה נראה נפלא',
#  'у меня сегодня день рождения',
#  'נהיה חברים לנצח',
#  'thank you so much',
#  'good thanks',
#  'איזה בוקר',
#  'באיזה תאריך נולדת',
#  'באיזו עיר אתה גר',
#  'באיזה יום יצרו אותך',
#  'alright thanks',
#  'very good thank you',
#  'אחלה תודה',
#  'אוקיי תודה',
#  "I'm very tired ",
#  'ניהייתי עייפה',
#  'איפה את מתגוררת',
#  'אתה נראה מעולה',
#  'where is your residence',
#  'you are a good friend',
#  'you look so well',
#  'פאק יו',
#  'לא רוצה לשמוע',
#  'רוצה להיות החבר הכי טוב שלי',
#  'good morning too',
#  'why are you so beautiful',
#  "Let's stop talking",
#  'תאריך הלידה שלך',
#  'אתה נראה מצוין',
#  'לא טוב לי',
#  'תודה על העזרה',
#  'תודה לך',
#  'ממש רע לי',
#  'ניסוי',
#  'את חברת ילדות',
#  'היי בוקר נפלא',
#  'אזלו כוחותיי',
#  'אני נהיה עייף',
#  'אני מדוכא',
#  'את מאוד מושכת',
#  'רב תודות',
#  'hello good morning',
#  'и еще раз спасибо',
#  'את חברת אמת',
#  "let's be friends",
#  'אני רוצה לבדוק אותך',
#  'מעולה תודה רבה',
#  'what is your residence',
#  'איפה את גרה',
#  'How old are you now?',
#  'אהלן וסהלן',
#  'анализ',
#  'איך ההורים שלך קראו לך',
#  'well thanks',
#  'в каком городе ты живешь',
#  'you look so good',
#  'תהיה החבר הכי טוב שלי',
#  'אני לא רוצה את הצאט הזה',
#  'i wanna know your age',
#  'אני בוחן אותך',
#  "where's your hometown",
#  'את מאוד מרשימה',
#  'אני תמיד אהיה חבר שלך',
#  'you look wonderful today',
#  'בא לי להיות חבר שלך',
#  'сегодня день вашего рождения',
#  "I'd like to know your age",
#  'how old is your platform',
#  'תהיה חבר שלי',
#  'אתה חבר ילדות שלי',
#  'you are so cute',
#  'גילך',
#  'מוודא שאתה עובד',
#  'you look so beautiful today',
#  'tell me about your city',
#  'הי עוזרת האישית',
#  'איך לקרוא לך',
#  "you're my dear friend",
#  "I don't want to talk",
#  'את נראית מדהים',
#  'Однако я устал',
#  'אני עייף',
#  'с добрым утром',
#  'אהלן',
#  'בוא נהיה חברים',
#  'your residence',
#  'עייפתי',
#  'i feel tired',
#  'you look great',
#  'I appreciate it',
#  'מאיפה אתה בארץ',
#  'you are looking pretty',
#  'you are really beautiful',
#  'hi there',
#  'בן כמה אתה',
#  'אנחנו חברים מעכשיו',
#  'Hello',
#  'you are very pretty',
#  'אני מת מעייפות',
#  'קול תודה',
#  'ממש עצוב לי',
#  'alright thank you',
#  'מצוין תודה לך',
#  "what's your city",
#  'age of yours',
#  'what is your hometown',
#  'מתי יש לך יומולדת',
#  'a good morning',
#  'are we friends',
#  'From how long you have been here?',
#  'I greet you',
#  "let's stop talking for a minute",
#  'you look amazing',
#  'I was born today',
#  'אני רוצה שתהיי חברה שלי',
#  'you are so beautiful today',
#  'מודה לך מקרב לב',
#  'תהיי חברה שלי',
#  'אני עצוב',
#  'and a good morning to you',
#  'באיזה עיר את גרה',
#  'how old were you',
#  'בוקר טוב חביבי',
#  'I want to have a friend like you',
#  'היי בוט',
#  "I'm drained",
#  'good morning there',
#  'can you be my best friend',
#  'בסדר גמור תודה',
#  '-123',
#  'בוקר נפלא גם לך',
#  'доброе утро',
#  'עייפה',
#  'today is my birthday',
#  'בת כמה את',
#  'טוב תודה לכם',
#  'את נראית מאוד טוב',
#  'אני עצוב מאוד',
#  'you are really pretty',
#  'I feel tired',
#  'כי את נראית כמו פרח',
#  'just going to say hi',
#  'you look so beautiful',
#  'מה הכתובת מגורים שלך',
#  'אני עייף מת',
#  'אתה מקסים',
#  'שמך',
#  'מאיפה את',
#  "I'm celebrating my birthday today",
#  'רק בודקת שאתה עובד',
#  'you look awesome',
#  'you are gorgeous',
#  'я устал',
#  'שלום בוקר טוב',
#  'how are you so pretty?',
#  'בוקר נעים',
#  'you look cool',
#  'are we still friends',
#  'אני רוצה שיהיה לי חבר כמוך',
#  'you are pretty',
#  'good morning to you',
#  'you look fantastic',
#  'עבר עלי יום ארוך אני גמור',
#  'cheers',
#  'באיזה תאריך את חוגגת יום הולדת',
#  "I'm not talking to you anymore",
#  'Can u pls stop talking',
#  'you look wonderful',
#  'אין לי כוח',
#  'сколько вам лет',
#  'מבחן',
#  'your name',
#  'היום יום ההולדת שלך',
#  'אנחנו חברים',
#  'תודה אין לי שאלה נוספת',
#  'пожелать доброго утра',
#  'проводит проверку',
#  'לי קוראים הרי ולך',
#  'you are my good friend',
#  'where is your hometown',
#  'אני מודה לך',
#  'רוצה להיות חבר שלי',
#  'אני רוצה שתהיה חבר שלי',
#  'огромное спасибо',
#  'אני רוצה שנהיה חברים טובים',
#  "i'm dead tired",
#  'לא רוצה לדבר יותר',
#  'כמה זמן הבוט הזה קיים',
#  'you are handsome',
#  'what is your age?',
#  'את מרשימה',
#  'hi',
#  'afternoon',
#  'אתה ממש חמוד',
#  'this is just a test',
#  'heya',
#  'you look perfect',
#  'שם משפחה',
#  'i was born on this day',
#  'היום זה יום ההולדת שלך',
#  'איזה שם נתנו לך',
#  'be my best friend',
#  'you are being tested',
#  'would you be my friend',
#  'בוקר נפלא',
#  'לא בא לי לדבר',
#  'can we be friends',
#  'שלום חברי',
#  'be my friend',
#  'I want to test you',
#  'חמוד',
#  'בדיקה בדיקה',
#  'תודה גבר',
#  "I don't want to talk to you",
#  'you look gorgeous',
#  'בדיקה',
#  'you are so beautiful',
#  'טוב תודה הבנתי',
#  'you are so gorgeous',
#  'שלום רב',
#  'i am awfully tired',
#  'רק מוודא שאתה תקין',
#  'בת כמה כת',
#  'שלום לך',
#  'לידה',
#  'רוצה להיות חברה שלי',
#  'באיזה איזור אתה גר',
#  'yaaaay it is my birthday',
#  'אתה מאוד חינני',
#  'אני פשוט גמורה',
#  "you're my childhood friend",
#  'מה העיר שאת גרה בה',
#  'עושה ניסוי',
#  'hello again',
#  'you are so beautiful to me',
#  'can we be best friends',
#  'מעולה תודה',
#  'hi good morning',
#  'your city',
#  'hola',
#  "I'm worn out",
#  'you are very cute',
#  'שמך יהיה יוספה',
#  "I don't like talking to you",
#  'testing chatbot',
#  'где ты живешь',
#  'thanks for your help',
#  'לא רוצה לדבר עם מחשב',
#  'Я устала',
#  'הי עוזר',
#  'תודה רבה רבה',
#  'how can i know about your age',
#  'what is your city',
#  'good morning',
#  'אתה נראה ממש מעולה',
#  'תדה רבה',
#  "I've overworked",
#  'היי היי',
#  'all thank you',
#  'לא רוצה להמשיך את השיחה',
#  'could you be my friend',
#  'thank you for your help',
#  'hello hi',
#  'את נראית טוב',
#  'you and me are friends',
#  'i am kind of so tired',
#  'מצוין תודה',
#  'you are so attractive',
#  'I like the way you look now',
#  'you are beautiful',
#  'אתה נראה מגניב',
#  'В каком месте ты живешь',
#  'הייייי',
#  'are you my best friend',
#  'אני מרגיש רע',
#  'אני גמור',
#  'אתה מהמם',
#  'what is your age as of today?',
#  'תודה אין שאלות',
#  'tell me how old you are',
#  'you look very pretty',
#  'שלום לך בוקר טוב',
#  "I'm exhausted",
#  'you are so pretty',
#  'appreciate your help',
#  "It's my born day",
#  'здравствуйте',
#  'אתה חבר שלי',
#  'כמה זמן זה קיים',
#  'יש לך גיל',
#  'nice thank you',
#  'בוקר טוב לך',
#  'stop your nuisance talk',
#  'באיזו ארץ אתה גר',
#  'אתה נאה',
#  'אתה נראה נהדר',
#  '👋🏻',
#  'אני לא רוצה לדבר',
#  'i was tired',
#  'you look amazing today',
#  'it is my birthday',
#  'מה שמך',
#  'מה התאריך לידה',
#  'שיהיה לך בוקר נפלא',
#  'testing',
#  'אני רוצה לדעת את הגיל שלך',
#  'בסדר תודה לך',
#  'אתה יכול להגיד לי מה הכתובת שלך',
#  'спасибо',
#  'בוקר בוקר',
#  'בוקר טוב לכם',
#  "you're attractive",
#  'את חברה שלי',
#  'מתי נולדת',
#  'אתה נראה ממש טוב',
#  'אפשר שנהיה חברים',
#  "I'm a bit tires",
#  'we are the best friends ever',
#  'would you like to be my friend',
#  'hello there',
#  'אתה חבר טוב',
#  'morning',
#  'היי סמרטי',
#  'let me test you',
#  'אנחנו ידידים',
#  'באיזה יום עשו אותך',
#  'top of the morning to you',
#  'приветствую',
#  'אתה יפה',
#  'תודה',
#  'מה שמך בבקשה',
#  'can you be my friend',
#  'מאיפה אתה',
#  'הי עוזרת',
#  'what is your town',
#  'howdy',
#  'לא רוצה לשמוע ממך',
#  'have a nice morning',
#  'is it your hometown',
#  'have a great morning',
#  'שלום עוזרת',
#  'thanks so much',
#  'we are friends',
#  'חחחח תודה רבה את ממש חכמה',
#  'בצ כמה את',
#  'thank you',
#  "you're cute",
#  'I like the way you look',
#  'אני מאוד עצוב',
#  'где ты жил',
#  'חמודה',
#  'you are too beautiful',
#  'תאריך יום ההולדת שלך',
#  'תודה על הכל',
#  'I am testing you',
#  'can I test you',
#  'I want to be your friend',
#  'תודה שעזרת לי',
#  'אני מותש',
#  'שיהיה לך בוקר מדהים',
#  'איך אני בודק אם את עובדת',
#  'я хочу пожелать тебе доброго утра',
#  'תודה אהובה',
#  'שלום בוקר נפלא',
#  'לא מעוניין לשמוע',
#  'בסדר תודה אפנה להם',
#  'אתה חבר שלי מהגן',
#  "you're pretty",
#  'אתה נראה מאוד טוב',
#  'אתה נראה טוב',
#  'חבר שלי מגיל 6',
#  'טוב תודה רבה',
#  'you are cutie']

# %%
# %%time

def make_plot(lang):
    return (lang[texts]
             .transform(Umap(2))
             .plot_interactive(annot=False)
             .properties(width=500, height=500, title=type(lang).__name__))

# make_plot(lang_cv) | make_plot(lang_bp) | make_plot(lang_use)
# Out:
# CPU times: user 8 µs, sys: 7 µs, total: 15 µs
# Wall time: 18.8 µs

# %%
lang_xlm  = SentenceTFMLanguage('xlm-r-100langs-bert-base-nli-mean-tokens')

# %%
make_plot(lang_xlm)
# Out:
# alt.Chart(...)

# %%
lang_STF  = SentenceTFMLanguage('LaBSE')

# %%
# alt.data_transformers.disable_max_rows()
make_plot(lang_STF)
# Out:
# alt.Chart(...)

# %%
df = lang_STF[texts].transform(Umap(2)).to_dataframe().reset_index()
df.columns = ['text', 'd1', 'd2']
df['label'] = ''
df.shape[0]

# %%
# Here's the global state object
state = {}
state['df'] = df.copy()
state['chart'] = InteractiveCharts(df.loc[lambda d: d['label'] == ''], labels=['group'])

# %%
# pd.set_option('display.max_colwidth', -1)

def show_draw_chart(b=None):
    with out_chart:
        out_chart.clear_output()
        out_labels.clear_output()
        state['chart'].dataf = state['df'].loc[lambda d: d['label'] == '']
        state['chart'].charts = []
        state['chart'].add_chart(x='d1', y='d2', legend=False)

def show_examples(b=None):
    with out_table:
        out_table.clear_output()
        tfm = InteractivePreprocessor(json_desc=state['chart'].data())
        subset = state['df'].pipe(tfm.pandas_pipe).loc[lambda d: d['group'] != 0]
#         display(subset.sample(min(15, subset.shape[0]))[['text']], )
        display(subset[['text']])

def assign_label(b=None):
    tfm = InteractivePreprocessor(json_desc=state['chart'].data())
    idx = state['df'].pipe(tfm.pandas_pipe).loc[lambda d: d['group'] != 0].index
    state['df'].iloc[idx, 3] = label_name.value
    with out_counter:
        out_counter.clear_output()
        n_lab = state['df'].loc[lambda d: d['label'] != ''].shape[0]
        print(f"{n_lab}/{state['df'].shape[0]} labelled")

def retrain_state(b=None):
    keep = list(state['df'].loc[lambda d: d['label'] == '']['text'])
    umap = Umap(2)
    new_df = EmbeddingSet(*[e for e in embset if e.name in keep]).transform(umap).to_dataframe().reset_index()
    new_df.columns = ['text', 'd1', 'd2']
    new_df['label'] = ''
    state['df'] = pd.concat([new_df, state['df'].loc[lambda d: d['label'] != '']])
    show_draw_chart(b)
    
def choose_label(b=None):
    with out_labels:
        out_labels.clear_output()
        labels = list(set(state['df'][state['df']['label'] != '']['label'].to_list()))
        display(pd.DataFrame({'Labels':labels}))
    
out_table = widgets.Output()
out_labels = widgets.Output()
out_chart = widgets.Output()
out_counter = widgets.Output()

label_name = widgets.Text("label name")

btn_examples = widgets.Button(
    description='Show Examples',
    icon='eye'
)

btn_label = widgets.Button(
    description='Add label',
    icon='check'
)

btn_retrain = widgets.Button(
    description='Retrain',
    icon='coffee'
)

btn_redraw = widgets.Button(
    description='Redraw',
    icon='check'
)

btn_choose_label = widgets.Button(
    description='Existed Labels',
    icon=''
)


btn_examples.on_click(show_examples)
btn_choose_label.on_click(choose_label)
btn_label.on_click(assign_label)
btn_redraw.on_click(show_draw_chart)
btn_retrain.on_click(retrain_state)

show_draw_chart()
display(widgets.VBox([widgets.HBox([btn_retrain, btn_examples, btn_redraw]), 
                      widgets.HBox([out_chart, out_table])]), 
        label_name, widgets.HBox([btn_label, out_counter]),
        out_labels, widgets.HBox([btn_choose_label]))

# %%
state['df']
# Out:
#                     text        d1         d2 label
# 0    אתה מאוד מושך        3.150455  7.217732
# 1    בוקר בוקר            1.736014 -1.990218
# 2    עושה ניסוי           6.045632  7.717301
# 3    היי                  0.395877  0.035965
# 4    אין לי כוח אני עייף  2.111082  9.824638   עייף
# ..                   ...       ...       ...    ...
# 387  תעבירו אותי לנציג    8.574843  12.701341
# 388  כי את נראית כמו פרח  4.135009  5.863996
# 389  אני פשוט גמורה       2.578921  9.713188   עייף
# 390  באיזו ארץ אתה גר    -1.485256  7.666509
# 391  באיזה עיר את גרה    -1.301632  7.625077
#
# [392 rows x 4 columns]

# %%
state['df'][state['df']['label'] != ''].to_csv('labeled_data.csv')

# %%
import pandas as pd


def create_rasa_files(path, create_files_path):
    """
    Converts an CSV file created with the specified format to RASA accepted nlu.md format

    path: path where the CSV file is present
    create_files_path: path where the nlu.md file needs to be created
    """
    df = pd.read_csv(r"{}".format(path))
    file = open(r'{}'.format(create_files_path), "w")
    intents = list(set(df['label'].to_list()))
    for item in intents:
        file.write("## intent: {intent_name}\n".format(intent_name=item))
        for i, sent in df[df['label'] == item].iterrows():
            file.write("- {}\n".format(sent['text']))
        file.write("\n")
    file.close()

create_rasa_files('labeled_data.csv', 'nlu.md')

# %%
create_rasa_files('labeled_data.csv', 'nlu.md')
